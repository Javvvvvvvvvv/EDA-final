# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/creditcardfraud/creditcard.csv

# %% [markdown]
# **# Group members: Sameen Amna (22317), Javeria Ishaque (22607), Naima Khan (22897), Nabiha Tariq (22592), Suha Ahmed (22602)**

# %% [markdown]
# **Credit Card Data**

# %%
import pandas as pd
DF= pd.read_csv('/kaggle/input/creditcardfraud/creditcard.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Data Preprocessing**

# %%
DF.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3  1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4  1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
DF.shape
DF.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
DF.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
DF.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -2.363095e-16  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std    1.000002e+00  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min   -1.642058e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%   -9.372174e-01 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%    2.131453e-01  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    8.552120e-01  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    1.996583e+00  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
DF.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(DF.Amount)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
plt.figure(figsize=(10, 5))
sns.distplot(DF.Amount)
# Out:
# /tmp/ipykernel_32/1701325470.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(DF.Amount)
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# **Histograms**

# %%
for i in range(1, 29):
    plt.figure(figsize=(8, 6))
    plt.hist(DF[f'V{i}'], bins=20, color='purple')
    plt.title(f'Histogram for V{i}')
    plt.xlabel(f'V{i}')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# **Scatterplots**

# %%
import pandas as pd
import random

feature_names = [f'V{i}' for i in range(1, 29)]

plt.figure(figsize=(16, 10))

for _ in range(15):
    feat1, feat2 = random.sample(feature_names, 2)
    plt.subplot(3, 5, _ + 1) 
    plt.scatter(DF[feat1], DF[feat2], color='pink')
    plt.title(f'{feat1} vs. {feat2}')
    plt.xlabel(feat1)
    plt.ylabel(feat2)

plt.tight_layout()
plt.show()

# %%
corr = DF.corr()
sns.set(font_scale=1.5)

plt.figure(figsize=(24,16))


sns.heatmap(corr[(corr >= 0.5)| (corr <= -0.1)],
            cmap='Reds', vmax=1.0, vmin=-1.0, linewidths = 1,
            annot=True, annot_kws={"size": 13}, square=True);

# %% [markdown]
# **PCA on Time**

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

column_to_pca = DF["Time"]

column_to_pca = column_to_pca.to_numpy()

column_to_pca = column_to_pca.reshape(-1, 1)

scaler = StandardScaler()
column_to_pca = scaler.fit_transform(column_to_pca)

n_components = 1  
pca = PCA(n_components=n_components)
pca.fit(column_to_pca)

transformed_column = pca.transform(column_to_pca)

DF["Time"] = transformed_column.flatten()

explained_variance_ratio = pca.explained_variance_ratio_[0]

print("Explained Variance Ratio:", explained_variance_ratio)
# Out:
# Explained Variance Ratio: 1.0

# %% [markdown]
# **Models, Confusion Matrices, and Performance**

# %%
X = DF.drop(columns='Class')
y = DF['Class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score,recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

numerical = X.select_dtypes(include=np.number).columns
categorical = X.select_dtypes(exclude=np.number).columns

# %%
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
])

categorical_transformer = Pipeline(steps=[
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)), 
])

preprocessor = ColumnTransformer(transformers=[
    ('numerical', numerical_transformer, numerical),
    ('categorical', categorical_transformer, categorical)
], remainder='passthrough')

classifiers = [
    SVC(random_state=20),
    DecisionTreeClassifier(random_state=20),
    RandomForestClassifier(random_state=20),
    SGDClassifier(random_state=20)
]

classifier_names = [
    'Support Vector Machine',
    'Decision Tree',
    'Random Forest',
    'Stochastic Gradient'
]

model_scores = []
precision_scores = []
recall_scores = []

# %%
for classifier, name in zip(classifiers, classifier_names):
    pipe1 = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('selector', SelectKBest(k=len(X.columns))),
        ('classifier', classifier)])
    yscaling_pred = pipe1.fit(x_train, y_train).predict(x_test)
    score = accuracy_score(y_test, yscaling_pred)
    
    score_percentage = f'{score * 100:.2f}'
    model_scores.append(score_percentage)
    
    cm = confusion_matrix(y_test, yscaling_pred)
    
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix - {name}')
    plt.show()
    
    precision = precision_score(y_test, yscaling_pred)
    recall = recall_score(y_test, yscaling_pred)
    
    precision_scores.append(precision)
    recall_scores.append(recall)
    print(classification_report(y_test, yscaling_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.96      0.74      0.84        93
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.87      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.77      0.85      0.81        93
#
#     accuracy                           1.00     56962
#    macro avg       0.88      0.92      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.94      0.82      0.87        93
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# ...

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, yscaling_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.86      0.61      0.72        93
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.81      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# **Model Performance**

# %%
model_performance = pd.DataFrame({
    'Classifier': classifier_names,
    'Accuracy Score (%)': model_scores 
}).sort_values('Accuracy Score (%)', ascending=False, ignore_index=True)

display(model_performance)

precision_recall_df = pd.DataFrame({
    'Classifier': classifier_names,
    'Precision': precision_scores,
    'Recall': recall_scores
}).sort_values('Precision', ascending=False, ignore_index=True)

display(precision_recall_df)
# Out:
#                Classifier Accuracy Score (%)
# 0           Random Forest              99.96
# 1  Support Vector Machine              99.95
# 2           Decision Tree              99.93
# 3     Stochastic Gradient              99.92
#                Classifier  Precision    Recall
# 0  Support Vector Machine   0.958333  0.741935
# 1           Random Forest   0.938272  0.817204
# 2     Stochastic Gradient   0.863636  0.612903
# 3           Decision Tree   0.766990  0.849462

# %% [markdown]
# **Precision/Recall Plots**

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_recall_curve

precision_recall = []

for classifier, name in zip(classifiers, classifier_names):
    pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('selector', SelectKBest(k=len(X.columns))),
        ('classifier', classifier)])
    
    y_pred = pipe.fit(x_train, y_train).predict(x_test)

    encoder = LabelEncoder()
    ytest_encoded = encoder.fit_transform(y_test)
    ypred_encoded = encoder.transform(y_pred)
    
    precision, recall, _ = precision_recall_curve(ytest_encoded, ypred_encoded, pos_label= 1)
    
    precision_recall.append({
        'Classifier': name,
        'Precision': precision,
        'Recall': recall
    })

for data in precision_recall:
    name = data['Classifier']
    precision = data['Precision']
    recall = data['Recall']
    
    plt.figure(figsize=(6, 4))
    plt.plot(recall, precision, marker='.')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve - {name}')
    plt.show()

# %% [markdown]
# **ROC graphs**

# %%
classifiers = [
    SVC(kernel='rbf', probability=True, random_state=20),
    DecisionTreeClassifier(random_state=20),
    RandomForestClassifier(random_state=20),
    SGDClassifier(loss='modified_huber', random_state=20)
]

# %%
for classifier, name in zip(classifiers, classifier_names):
    pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('selector', SelectKBest(k=len(X.columns))),
    ('classifier', classifier)
    ])
    y_pred_prob = pipe.fit(x_train, y_train).predict_proba(x_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob, pos_label=1)
    roc = RocCurveDisplay(fpr=fpr, tpr=tpr)
    roc.plot()
    plt.title(f"{name} ROC Curve")
    plt.show()

# %% [markdown]
# **Hyperparameter Tuning**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold

# %%
rf_classifier = RandomForestClassifier()
param_grid = {
    'n_estimators': [50, 100, 200],
    'random_state': [13],
    'max_depth': [5, 10, 12]
}
grid_1 = GridSearchCV(rf_classifier,param_grid, cv=2)
grid_1.fit(x_train, y_train)

print('Best parameters: ', grid_1.best_params_)
print('Best score: ', grid_1.best_score_)
# Out:
# Best parameters:  {'max_depth': 12, 'n_estimators': 50, 'random_state': 13}
# Best score:  0.9994645484215552

# %% [markdown]
# **Ensemble**

# %%
from sklearn.ensemble import VotingClassifier

numerical = X.select_dtypes(include=np.number).columns
categorical = X.select_dtypes(exclude=np.number).columns

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
])

categorical_transformer = Pipeline(steps=[
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
])

preprocessor = ColumnTransformer(transformers=[
    ('num', numerical_transformer, numerical),
    ('cat', categorical_transformer, categorical)
])

classifiers = [
    ('svc', SVC(random_state=20)),
    ('decision_tree', DecisionTreeClassifier(random_state=20)),
    ('random_forest', RandomForestClassifier(random_state=20)),
    ('sgd', SGDClassifier(random_state=20))
]

ensemble_classifier = VotingClassifier(estimators=classifiers, voting='hard')

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', ensemble_classifier)])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label=1)
recall = recall_score(y_test, y_pred, pos_label=1)
f1 = f1_score(y_test, y_pred, pos_label=1)

print(f'Accuracy (%): {accuracy*100:.2f}')
print(f'Precision (%): {precision*100:.2f}')
print(f'Recall (%): {recall*100:.2f}')
print(f'F1 Score (%): {f1*100:.2f}')
# Out:
# Accuracy (%): 99.95
# Precision (%): 92.54
# Recall (%): 70.45
# F1 Score (%): 80.00

# %% [markdown]
# Of all the classifiers used, Random Forest Classifier (without hyperparameter tuning) gave the highest accuracy of 99.96% (1.0) and f1 score of 0.87. With the hyperparameter tuning using GridSearchCV, the accuracy was increased to 0.999. With the ensemble classification the accuracy dropped to 99.95 and f1 score to 0.80 which is less than the Random Forest Classifier. Therefore, the individual classifiers especially Random Forest turned out to be the best estimator after Hyperparameter tuning.
